# %%
import pandas as pd
import numpy as np

# %%
#Read the file into pandas
income = pd.read_csv('https://raw.githubusercontent.com/mandiemannz/personalincome1/master/personal_income1.csv')
income
# Out:
#        Table 2.1. Personal Income and Its Disposition  \
# 0   [Billions of dollars] Seasonally adjusted at a...
# 1                        Bureau of Economic Analysis
# 2   Last Revised on: February 28, 2017 - Next Rele...
# 3                                                Line
# 4                                                Line
# 5                                                   1
# 6                                                   2
# 7                                                   3
# 8                                                   4
# 9                                                   5
# 10                                                  6
# 11                                                  7
# 12                                                  8
# 13                                                  9
# 14                                                 10
# 15                                                 11
# ...

# %% [markdown]
# Drop the first 3 and last 6 rows that has null values.

# %%
newincome = income.drop(income.index[[0,1,2,51,52,53,54,55,56]])
newincome.head()
# Out:
#   Table 2.1. Personal Income and Its Disposition  \
# 3                                           Line
# 4                                           Line
# 5                                              1
# 6                                              2
# 7                                              3
#
#                       Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 3                                      2014       2014       2014       2014
# 4                                         I         II        III         IV
# 5                Personal income    14487.2    14718.1    14927.5    15106.2
# 6      Compensation of employees     9108.3     9173.8     9299.6     9432.1
# 7             Wages and salaries     7350.3     7405.7     7516.5     7632.8
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 3       2015       2015       2015       2015        2016        2016
# ...

# %%
#Rename all the columns
newincome.rename(columns={'Unnamed: 1':'Name', 'Unnamed: 2':'Q12014', 'Unnamed: 3':'Q22014', 'Unnamed: 4':'Q32014', 'Unnamed: 5':'Q42014'}, inplace=True)
newincome.columns
# Out:
# Index(['Table 2.1. Personal Income and Its Disposition', 'Name', 'Q12014',
#        'Q22014', 'Q32014', 'Q42014', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13'],
#       dtype='object')

# %%
newincome.rename(columns={'Unnamed: 6':'Q12015', 'Unnamed: 7':'Q22015', 'Unnamed: 8':'Q32015', 'Unnamed: 9':'Q42015'}, inplace=True)
newincome.columns
# Out:
# Index(['Table 2.1. Personal Income and Its Disposition', 'Name', 'Q12014',
#        'Q22014', 'Q32014', 'Q42014', 'Q12015', 'Q22015', 'Q32015', 'Q42015',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
newincome.rename(columns={'Unnamed: 10':'Q12016', 'Unnamed: 11':'Q22016', 'Unnamed: 12':'Q32016', 'Unnamed: 13':'Q42016'}, inplace=True)
newincome.columns
# Out:
# Index(['Table 2.1. Personal Income and Its Disposition', 'Name', 'Q12014',
#        'Q22014', 'Q32014', 'Q42014', 'Q12015', 'Q22015', 'Q32015', 'Q42015',
#        'Q12016', 'Q22016', 'Q32016', 'Q42016'],
#       dtype='object')

# %%
#Check for any null values
newincome.isnull().head()
# Out:
#   Table 2.1. Personal Income and Its Disposition   Name Q12014 Q22014 Q32014  \
# 3                                          False  False  False  False  False
# 4                                          False  False  False  False  False
# 5                                          False  False  False  False  False
# 6                                          False  False  False  False  False
# 7                                          False  False  False  False  False
#
#   Q42014 Q12015 Q22015 Q32015 Q42015 Q12016 Q22016 Q32016 Q42016
# 3  False  False  False  False  False  False  False  False  False
# 4  False  False  False  False  False  False  False  False  False
# 5  False  False  False  False  False  False  False  False  False
# 6  False  False  False  False  False  False  False  False  False
# 7  False  False  False  False  False  False  False  False  False

# %%
#Check the shape of the table
newincome.shape
# Out:
# (48, 14)

# %%
newincome.isnull().sum()
# Out:
# Table 2.1. Personal Income and Its Disposition    0
# Name                                              0
# Q12014                                            4
# Q22014                                            4
# Q32014                                            4
# Q42014                                            4
# Q12015                                            4
# Q22015                                            4
# Q32015                                            4
# Q42015                                            4
# Q12016                                            4
# Q22016                                            4
# Q32016                                            4
# Q42016                                            4
# dtype: int64

# %%
#Check the personal income, compensation and wages for 2014 and 2015
twokfourteen = newincome[['Name', 'Q12014', 'Q22014', 'Q32014', 'Q42014','Q12015', 'Q22015', 'Q32015', 'Q42015']]
twokfourteen.head()
# Out:
#                             Name   Q12014   Q22014   Q32014   Q42014   Q12015  \
# 3                                    2014     2014     2014     2014     2015
# 4                                       I       II      III       IV        I
# 5                Personal income  14487.2  14718.1  14927.5  15106.2  15185.9
# 6      Compensation of employees   9108.3   9173.8   9299.6   9432.1   9502.3
# 7             Wages and salaries   7350.3   7405.7   7516.5   7632.8     7692
#
#     Q22015   Q32015   Q42015
# 3     2015     2015     2015
# 4       II      III       IV
# 5  15401.9  15556.1  15690.2
# 6   9637.6     9740   9892.4
# 7   7808.8   7893.9   8024.6
